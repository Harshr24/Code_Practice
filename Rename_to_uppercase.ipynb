# %%
import os

# Function to rename files to uppercase
def rename_files_to_uppercase(directory):
    for root, dirs, files in os.walk(directory):
        for file in files:
            old_file_path = os.path.join(root, file)
            new_file_name = file.upper()
            new_file_path = os.path.join(root, new_file_name)

            if old_file_path != new_file_path:
                os.rename(old_file_path, new_file_path)
                print(f"Renamed: {old_file_path} -> {new_file_path}")

# Rename files in the current directory
rename_files_to_uppercase('.')
# Out:
# Renamed: .\AbstractClass.java -> .\ABSTRACTCLASS.JAVA
# Renamed: .\Abstraction.java -> .\ABSTRACTION.JAVA
# Renamed: .\Acircle.java -> .\ACIRCLE.JAVA
# Renamed: .\ActivitySelection.java -> .\ACTIVITYSELECTION.JAVA
# Renamed: .\Array.java -> .\ARRAY.JAVA
# Renamed: .\ArraySortedOrNot.java -> .\ARRAYSORTEDORNOT.JAVA
# Renamed: .\Asquare.java -> .\ASQUARE.JAVA
# Renamed: .\Average.java -> .\AVERAGE.JAVA
# Renamed: .\BacktrackingArray.java -> .\BACKTRACKINGARRAY.JAVA
# Renamed: .\BalancedBST.java -> .\BALANCEDBST.JAVA
# Renamed: .\binarySearch.java -> .\BINARYSEARCH.JAVA
# Renamed: .\BinarySearchTrees.java -> .\BINARYSEARCHTREES.JAVA
# Renamed: .\BinaryStringProblem.java -> .\BINARYSTRINGPROBLEM.JAVA
# Renamed: .\BinaryToDecimal.java -> .\BINARYTODECIMAL.JAVA
# Renamed: .\BinomialCofficient.java -> .\BINOMIALCOFFICIENT.JAVA
# Renamed: .\BitManipulation.java -> .\BITMANIPULATION.JAVA
# Renamed: .\BSTtoBalancedBST.java -> .\BSTTOBALANCEDBST.JAVA
# ...

# %%
import os

# Function to rename files to capitalize the first letter
def rename_files_to_capitalize(directory):
    for root, dirs, files in os.walk(directory):
        for file in files:
            old_file_path = os.path.join(root, file)
            # Capitalize the first letter of the file name and lowercase the rest
            new_file_name = file.capitalize()
            new_file_path = os.path.join(root, new_file_name)

            if old_file_path != new_file_path:
                os.rename(old_file_path, new_file_path)
                print(f"Renamed: {old_file_path} -> {new_file_path}")

# Rename files in the current directory
rename_files_to_capitalize('.')
# Out:
# Renamed: .\ABSTRACTCLASS.JAVA -> .\Abstractclass.java
# Renamed: .\ABSTRACTION.JAVA -> .\Abstraction.java
# Renamed: .\ACIRCLE.JAVA -> .\Acircle.java
# Renamed: .\ACTIVITYSELECTION.JAVA -> .\Activityselection.java
# Renamed: .\ARRAY.JAVA -> .\Array.java
# Renamed: .\ARRAYSORTEDORNOT.JAVA -> .\Arraysortedornot.java
# Renamed: .\ASQUARE.JAVA -> .\Asquare.java
# Renamed: .\AVERAGE.JAVA -> .\Average.java
# Renamed: .\BACKTRACKINGARRAY.JAVA -> .\Backtrackingarray.java
# Renamed: .\BALANCEDBST.JAVA -> .\Balancedbst.java
# Renamed: .\BINARYSEARCH.JAVA -> .\Binarysearch.java
# Renamed: .\BINARYSEARCHTREES.JAVA -> .\Binarysearchtrees.java
# Renamed: .\BINARYSTRINGPROBLEM.JAVA -> .\Binarystringproblem.java
# Renamed: .\BINARYTODECIMAL.JAVA -> .\Binarytodecimal.java
# Renamed: .\BINOMIALCOFFICIENT.JAVA -> .\Binomialcofficient.java
# Renamed: .\BITMANIPULATION.JAVA -> .\Bitmanipulation.java
# Renamed: .\BSTTOBALANCEDBST.JAVA -> .\Bsttobalancedbst.java
# ...

# %%
import os

def rename_files_to_capitalize(directory):
    for root, dirs, files in os.walk(directory):
        for file in files:
            old_file_path = os.path.join(root, file)
            temp_file_name = f"temp_{file}"  # Temporary name
            temp_file_path = os.path.join(root, temp_file_name)
            new_file_name = file.capitalize()  # Desired name
            new_file_path = os.path.join(root, new_file_name)

            # Rename to a temporary file first, then to the final name
            os.rename(old_file_path, temp_file_path)
            os.rename(temp_file_path, new_file_path)
            print(f"Renamed: {old_file_path} -> {new_file_name}")

# Rename files in the current directory
rename_files_to_capitalize('.')
# Out:
# Renamed: .\Abstractclass.java -> Abstractclass.java
# Renamed: .\Abstraction.java -> Abstraction.java
# Renamed: .\Acircle.java -> Acircle.java
# Renamed: .\Activityselection.java -> Activityselection.java
# Renamed: .\add.java -> Add.java
# Renamed: .\Animal.java -> Animal.java
# Renamed: .\area.java -> Area.java
# Renamed: .\Array.java -> Array.java
# Renamed: .\Arraysortedornot.java -> Arraysortedornot.java
# Renamed: .\Asquare.java -> Asquare.java
# Renamed: .\Average.java -> Average.java
# Renamed: .\Backtrackingarray.java -> Backtrackingarray.java
# Renamed: .\Balancedbst.java -> Balancedbst.java
# Renamed: .\BankAcc.java -> Bankacc.java
# Renamed: .\Binarysearch.java -> Binarysearch.java
# Renamed: .\Binarysearchtrees.java -> Binarysearchtrees.java
# Renamed: .\Binarystringproblem.java -> Binarystringproblem.java
# Renamed: .\Binarytodecimal.java -> Binarytodecimal.java
# Renamed: .\Binomialcofficient.java -> Binomialcofficient.java
# ...
